# %%
# %pip install torch transformers datasets evaluate

# %%
import pandas as pd
import numpy as np
import torch
from datasets import Dataset, load_dataset
import evaluate
from transformers import CamembertTokenizer, CamembertForSequenceClassification, Trainer, TrainingArguments
# Out:
# WARNING:tensorflow:From c:\Users\User\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ### Loading Data

# %%
df_b24 = pd.read_json("burkina24_training_data.json")
df_b24.head()
# Out:
#                                                 text  label  \
# 0  Dans le cadre du mois d’Octobre Rose\n\n, Oran...  Santé
# 1  Le projet PLURIELLES, financé par Affaires mon...  Santé
# 2  L’autrice de la bande dessinée « Une vie pour ...  Santé
# 3  Le dimanche 17 août 2025, l’association Laafi ...  Santé
# 4  Chaque 28 juillet, la communauté international...  Santé
#
#                                                title                 author  \
# 0  Octobre Rose : La Fondation Orange Burkina Fas...                Akim Ky
# 1  Projet PLURIELLES : Un pas de géant pour la re...  Flora Toelo Karambiri
# 2  Lutte contre la dépigmentation au Burkina Faso...      Abdoul Gani Barry
# 3  Santé Publique : L’Association Laafi sans fron...          Rédaction B24
# 4  Santé : Le Burkina Faso commémore la journée m...            Willy SAGBE
#
#                  date                                                url  \
# 0 2025-10-20 19:07:44  https://burkina24.com/2025/10/20/octobre-rose-...
# 1 2025-09-23 17:30:02  https://burkina24.com/2025/09/23/projet-plurie...
# 2 2025-08-16 10:30:25  https://burkina24.com/2025/08/16/lutte-contre-...
# 3 2025-08-18 08:31:57  https://burkina24.com/2025/08/18/sante-publiqu...
# 4 2025-08-18 14:24:54  https://burkina24.com/2025/08/18/sante-le-burk...
#
#               category_raw      media  \
# 0  actualite/societe/sante  Burkina24
# 1  actualite/societe/sante  Burkina24
# 2  actualite/societe/sante  Burkina24
# 3  actualite/societe/sante  Burkina24
# 4  actualite/societe/sante  Burkina24
#
#                                            image_url tags  \
# 0  https://burkina24.com/wp-content/uploads/2025/...   []
# 1  https://burkina24.com/wp-content/uploads/2025/...   []
# 2  https://burkina24.com/wp-content/uploads/2023/...   []
# 3  https://burkina24.com/wp-content/uploads/2025/...   []
# 4  https://burkina24.com/wp-content/uploads/2025/...   []
#
#                   scraped_at
# 0 2025-11-16 13:04:46.207099
# 1 2025-11-16 13:04:47.021270
# 2 2025-11-16 13:04:47.911046
# 3 2025-11-16 13:04:49.285769
# 4 2025-11-16 13:04:50.449480

# %%
# required categories
categories = ["Politique", "Économie", "Sécurité", "Santé", "Culture", "Sport", "Autres"]

# %% [markdown]
# #### b24 column mapping

# %%
df_b24["label"].value_counts()
# Out:
# label
# Économie     160
# Sécurité     155
# Sport        154
# Santé        152
# Politique    145
# Culture      136
# Name: count, dtype: int64

# %%
df_b24["label"] = df_b24["label"].apply(
    lambda x: x if x in categories else "Autres"
)
# -> No label mapped to "Autres"
df_b24["label"].value_counts()
# Out:
# label
# Économie     160
# Sécurité     155
# Sport        154
# Santé        152
# Politique    145
# Culture      136
# Name: count, dtype: int64

# %% [markdown]
# #### Fasonet mapping

# %%
df_faso = pd.read_json("lefaso_training_data.json")
df_faso["label"].value_counts()
# Out:
# label
# International    400
# Politique        200
# Économie         200
# Société          200
# Sport            200
# Culture          200
# Name: count, dtype: int64

# %%
df_faso["label"] = df_faso["label"].apply(
    lambda x: x if x in categories else "Autres"
)
# -> "International" and "Société" mapped to "Autres"
df_faso["label"].value_counts()
# Out:
# label
# Autres       600
# Politique    200
# Économie     200
# Sport        200
# Culture      200
# Name: count, dtype: int64

# %% [markdown]
# #### Sidwaya mapping

# %%
df_sdya = pd.read_json("sidwaya_training_data.json")
df_sdya["label"].value_counts()
# Out:
# label
# Sport       377
# Sécurité     78
# Name: count, dtype: int64

# %%
df_sdya["label"] = df_sdya["label"].apply(
    lambda x: x if x in categories else "Autres"
)
# -> No label mapped to "Autres"
df_sdya["label"].value_counts()
# Out:
# label
# Sport       377
# Sécurité     78
# Name: count, dtype: int64

# %% [markdown]
# #### Merging three datasets

# %%
df_merged = pd.concat([df_faso, df_b24, df_sdya], ignore_index=True)
df_merged
# Out:
#                                                    text      label  \
# 0     Parmi ces décisions, il y a le bilan à mi-parc...  Politique
# 1     Le premier ministre, Rimtalba Jean Emmanuel  O...  Politique
# 2     Photo d’illustration\n\nIl est 10 h, lorsque l...  Politique
# 3     Cette visite intervient après les propos, débu...  Politique
# 4     Le 30 mai 2017 s’éteignait en France Dr Valère...  Politique
# ...                                                 ...        ...
# 2752  L’Association sportive des Douanes a battu en ...      Sport
# 2753  Malmenée par la presse française pour son hygi...      Sport
# 2754  La Fédération burkinabè de football (FBF) a or...      Sport
# 2755  L’histoire retiendra, ce 21 août 2023 que Hugu...      Sport
# 2756  Le Capitaine Ibrahim Traore, président de la t...      Sport
#
#                                                   title          author  \
# 0     Burkina Faso : Certaines grandes entreprises o...          Lefaso
# 1     Burkina/Évaluation des ministres : La ministre...          Lefaso
# 2     Burkina/ Assemblée législative de Transition :...          Lefaso
# 3     Diplomatie : Un émissaire du président Donald ...          Lefaso
# 4     Témoignage : Valère, mon maître idéologique et...          Lefaso
# ...                                                 ...             ...
# 2752  30e édition Super coupe AJSB : les Gabelous co...     JK. Sidwaya
# 2753  Al Hilal: Les supporters s’arrachent le maillo...  Wamini SIDWAYA
# 2754  Assemblée générale ordinaire de la FBF: les ac...     JK. Sidwaya
# 2755  Mondiaux d’athlétisme: de l’or historique pour...     JK. Sidwaya
# 2756  Athlétisme : Le Capitaine Ibrahim Traore félic...  Wamini SIDWAYA
#
#                     date                                                url  \
# 0                    NaT          https://lefaso.net/spip.php?article141410
# 1                    NaT          https://lefaso.net/spip.php?article139922
# 2                    NaT          https://lefaso.net/spip.php?article138343
# 3                    NaT          https://lefaso.net/spip.php?article138459
# 4                    NaT          https://lefaso.net/spip.php?article138433
# ...                  ...                                                ...
# 2752 2023-08-06 22:41:18  https://www.sidwaya.info/30e-edition-super-cou...
# 2753 2023-08-16 12:54:58  https://www.sidwaya.info/al-hilal-les-supporte...
# 2754 2023-08-20 22:10:38  https://www.sidwaya.info/assemblee-generale-or...
# 2755 2023-08-21 22:34:06  https://www.sidwaya.info/mondiaux-dathletisme-...
# 2756 2023-08-22 12:39:17  https://www.sidwaya.info/athletisme-le-capitai...
#
#      category_raw       media  \
# 0       politique  Lefaso.net
# 1       politique  Lefaso.net
# 2       politique  Lefaso.net
# 3       politique  Lefaso.net
# 4       politique  Lefaso.net
# ...           ...         ...
# 2752        Sport     Sidwaya
# 2753        Sport     Sidwaya
# 2754        Sport     Sidwaya
# 2755        Sport     Sidwaya
# 2756        Sport     Sidwaya
#
#                                               image_url tags  \
# 0                                                         []
# 1                                                         []
# 2                                                         []
# 3                                                         []
# 4                                                         []
# ...                                                 ...  ...
# 2752  https://www.sidwaya.info/wp-content/uploads/20...   []
# 2753  https://www.sidwaya.info/wp-content/uploads/20...   []
# 2754  https://www.sidwaya.info/wp-content/uploads/20...   []
# 2755  https://www.sidwaya.info/wp-content/uploads/20...   []
# 2756  https://www.sidwaya.info/wp-content/uploads/20...   []
#
#                      scraped_at
# 0    2025-11-16 12:34:15.912026
# 1    2025-11-16 12:34:17.220251
# 2    2025-11-16 12:34:18.107721
# 3    2025-11-16 12:34:19.970300
# 4    2025-11-16 12:34:21.030728
# ...                         ...
# 2752 2025-11-16 15:49:32.091149
# 2753 2025-11-16 15:49:33.441009
# 2754 2025-11-16 15:49:34.679212
# 2755 2025-11-16 15:49:35.710802
# 2756 2025-11-16 15:49:37.012966
#
# [2757 rows x 11 columns]

# %%
df_merged["label"].value_counts()
# Out:
# label
# Sport        731
# Autres       600
# Économie     360
# Politique    345
# Culture      336
# Sécurité     233
# Santé        152
# Name: count, dtype: int64

# %%
df_merged.to_json("final_dataset.json", indent=2)

# %% [markdown]
# #### Training

# %%
import torch
# import pandas as pd

# Your label counts
label_counts = {
    "Sport": 731,
    "Autres": 600,
    "Économie": 360,
    "Politique": 345,
    "Culture": 336,
    "Sécurité": 233,
    "Santé": 152
}

# Map labels to IDs
label_to_id = {label: i for i, label in enumerate(label_counts.keys())}
id_to_label = {v: k for k, v in label_to_id.items()}

num_labels = len(label_counts)

# Convert counts into weights
counts = torch.tensor(list(label_counts.values()), dtype=torch.float)
class_weights = 1.0 / counts
class_weights = class_weights / class_weights.sum() * num_labels  # normalize

print("Class weights:", class_weights)
# Out:
# Class weights: tensor([0.4245, 0.5172, 0.8620, 0.8995, 0.9235, 1.3318, 2.0415])

# %%
from sklearn.model_selection import train_test_split

train_df, val_df = train_test_split(
    df_merged,
    test_size=0.2,
    stratify=df_merged["label"],   # 🔥 ensures balanced categories
    random_state=42
)

# val_df, test_df = train_test_split(
#     test_df,
#     test_size=0.5,
#     stratify=test_df["label"],   # 🔥 ensures balanced categories
#     random_state=42
# )

# %%
from torch.utils.data import Dataset, DataLoader
from transformers import CamembertTokenizer

tokenizer = CamembertTokenizer.from_pretrained("camembert-base")

class NewsDataset(Dataset):
    def __init__(self, df):
        self.texts = df["text"].tolist()
        self.labels = df["label"].map(label_to_id).tolist()

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        encoding = tokenizer(
            self.texts[idx],
            truncation=True,
            padding="max_length",
            max_length=256
        )
        return {
            "input_ids": torch.tensor(encoding["input_ids"]),
            "attention_mask": torch.tensor(encoding["attention_mask"]),
            "labels": torch.tensor(self.labels[idx])
        }

train_dataset = NewsDataset(train_df)
val_dataset = NewsDataset(val_df)

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=8)
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# c:\Users\User\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\User\.cache\huggingface\hub\models--camembert-base. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# sentencepiece.bpe.model:   0%|          | 0.00/811k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.40M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/508 [00:00<?, ?B/s]
# c:\Users\User\anaconda3\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
from transformers import CamembertForSequenceClassification
import torch.nn as nn

model = CamembertForSequenceClassification.from_pretrained(
    "camembert-base",
    num_labels=num_labels
)

# Weighted CrossEntropyLoss
criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5)
# Out:
# model.safetensors:   0%|          | 0.00/445M [00:00<?, ?B/s]
# Some weights of CamembertForSequenceClassification were not initialized from the model checkpoint at camembert-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
criterion.to(device)

for epoch in range(10):
    model.train()
    total_loss = 0

    for batch in train_loader:
        optimizer.zero_grad()

        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["labels"].to(device)

        outputs = model(
            input_ids=input_ids,
            attention_mask=attention_mask,
            labels=None  # we compute loss manually
        )

        logits = outputs.logits
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    print(f"Epoch {epoch+1} - Training Loss: {total_loss/len(train_loader):.4f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 18
#      15 attention_mask = batch["attention_mask"].to(device)
#      16 labels = batch["labels"].to(device)
# ---> 18 outputs = model(
#      19     input_ids=input_ids,
#      20     attention_mask=attention_mask,
#      21     labels=None  # we compute loss manually
#      22 )
#      24 logits = outputs.logits
#      25 loss = criterion(logits, labels)
#
# File c:\Users\User\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\User\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\User\anaconda3\Lib\site-packages\transformers\models\camembert\modeling_camembert.py:1064, in CamembertForSequenceClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1056 r"""
#    1057 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#    1058     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#    1059     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#    1060     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1061 """
#    1062 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1064 outputs = self.roberta(
#    1065     input_ids,
#    1066     attention_mask=attention_mask,
#    1067     token_type_ids=token_type_ids,
#    1068     position_ids=position_ids,
#    1069     head_mask=head_mask,
#    1070     inputs_embeds=inputs_embeds,
#    1071     output_attentions=output_attentions,
#    1072     output_hidden_states=output_hidden_states,
#    1073     return_dict=return_dict,
#    1074 )
#    1075 sequence_output = outputs[0]
#    1076 logits = self.classifier(sequence_output)
#
# File c:\Users\User\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\User\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\User\anaconda3\Lib\site-packages\transformers\models\camembert\modeling_camembert.py:889, in CamembertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     880 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     882 embedding_output = self.embeddings(
#     883     input_ids=input_ids,
#     884     position_ids=position_ids,
#    (...)
#     887     past_key_values_length=past_key_values_length,
#     888 )
# --> 889 encoder_outputs = self.encoder(
#     890     embedding_output,
#     891     attention_mask=extended_attention_mask,
#     892     head_mask=head_mask,
#     893     encoder_hidden_states=encoder_hidden_states,
#     894     encoder_attention_mask=encoder_extended_attention_mask,
#     895     past_key_values=past_key_values,
#     896     use_cache=use_cache,
#     897     output_attentions=output_attentions,
#     898     output_hidden_states=output_hidden_states,
#     899     return_dict=return_dict,
#     900 )
#     901 sequence_output = encoder_outputs[0]
#     902 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File c:\Users\User\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\User\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\User\anaconda3\Lib\site-packages\transformers\models\camembert\modeling_camembert.py:539, in CamembertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     528     layer_outputs = self._gradient_checkpointing_func(
#     529         layer_module.__call__,
#     530         hidden_states,
#    (...)
#     536         output_attentions,
#     537     )
#     538 else:
# --> 539     layer_outputs = layer_module(
#     540         hidden_states,
#     541         attention_mask,
#     542         layer_head_mask,
#     543         encoder_hidden_states,
#     544         encoder_attention_mask,
#     545         past_key_value,
#     546         output_attentions,
#     547     )
#     549 hidden_states = layer_outputs[0]
#     550 if use_cache:
#
# File c:\Users\User\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\User\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\User\anaconda3\Lib\site-packages\transformers\models\camembert\modeling_camembert.py:428, in CamembertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     416 def forward(
#     417     self,
#     418     hidden_states: torch.Tensor,
#    (...)
#     425 ) -> Tuple[torch.Tensor]:
#     426     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     427     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 428     self_attention_outputs = self.attention(
#     429         hidden_states,
#     430         attention_mask,
#     431         head_mask,
#     432         output_attentions=output_attentions,
#     433         past_key_value=self_attn_past_key_value,
#     434     )
#     435     attention_output = self_attention_outputs[0]
#     437     # if decoder, the last output is tuple of self-attn cache
#
# File c:\Users\User\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\User\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\User\anaconda3\Lib\site-packages\transformers\models\camembert\modeling_camembert.py:355, in CamembertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     345 def forward(
#     346     self,
#     347     hidden_states: torch.Tensor,
#    (...)
#     353     output_attentions: Optional[bool] = False,
#     354 ) -> Tuple[torch.Tensor]:
# --> 355     self_outputs = self.self(
#     356         hidden_states,
#     357         attention_mask,
#     358         head_mask,
#     359         encoder_hidden_states,
#     360         encoder_attention_mask,
#     361         past_key_value,
#     362         output_attentions,
#     363     )
#     364     attention_output = self.output(self_outputs[0], hidden_states)
#     365     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File c:\Users\User\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\User\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\User\anaconda3\Lib\site-packages\transformers\models\camembert\modeling_camembert.py:278, in CamembertSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     274 attention_probs = nn.functional.softmax(attention_scores, dim=-1)
#     276 # This is actually dropping out entire tokens to attend to, which might
#     277 # seem a bit unusual, but is taken from the original Transformer paper.
# --> 278 attention_probs = self.dropout(attention_probs)
#     280 # Mask heads if we want to
#     281 if head_mask is not None:
#
# File c:\Users\User\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\User\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\User\anaconda3\Lib\site-packages\torch\nn\modules\dropout.py:59, in Dropout.forward(self, input)
#      58 def forward(self, input: Tensor) -> Tensor:
# ---> 59     return F.dropout(input, self.p, self.training, self.inplace)
#
# File c:\Users\User\anaconda3\Lib\site-packages\torch\nn\functional.py:1295, in dropout(input, p, training, inplace)
#    1293 if p < 0.0 or p > 1.0:
#    1294     raise ValueError(f"dropout probability has to be between 0 and 1, but got {p}")
# -> 1295 return _VF.dropout_(input, p, training) if inplace else _VF.dropout(input, p, training)
#
# KeyboardInterrupt:

# %%
df["label"].value_counts()
# Out:
# label
# 1    607
# 2    299
# 0     94
# Name: count, dtype: int64

# %%
# ✅ Load CamemBERT tokenizer
tokenizer = CamembertTokenizer.from_pretrained("camembert-base")

# ✅ Tokenization function
def tokenize_function(examples):
    return tokenizer(examples["text"], padding="max_length", truncation=True)

# %%
# ✅ Split dataset: 80% train, 20% validation
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(df, test_size=0.2, random_state=42)

# train_df = df.iloc[:800]  # First 800 rows for training
# val_df = df.iloc[800:]    # Last 200 rows for validation

# ✅ Convert Pandas DataFrame to Hugging Face Dataset
train_dataset = Dataset.from_pandas(train_df)
val_dataset = Dataset.from_pandas(val_df)

# %%
# ✅ Tokenize datasets
train_dataset = train_dataset.map(tokenize_function, batched=True)
val_dataset = val_dataset.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/800 [00:00<?, ? examples/s]
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]

# %%
# ✅ Load CamemBERT model (3 classes: Negative, Neutral, Positive)
model = CamembertForSequenceClassification.from_pretrained("camembert-base", num_labels=3)
# Out:
# Some weights of CamembertForSequenceClassification were not initialized from the model checkpoint at camembert-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='1000' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1000/1000 14:45, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.707877</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.570179</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.538728</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.567626</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.481000</td>
#       <td>0.603477</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.481000</td>
#       <td>0.571581</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.481000</td>
#       <td>0.593409</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.481000</td>
#       <td>0.614455</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.481000</td>
#       <td>0.617528</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.134400</td>
#       <td>0.630720</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1000, training_loss=0.30769239044189456, metrics={'train_runtime': 886.6395, 'train_samples_per_second': 9.023, 'train_steps_per_second': 1.128, 'total_flos': 2104907341824000.0, 'train_loss': 0.30769239044189456, 'epoch': 10.0})

# %%
# ✅ Training arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=10,
    weight_decay=0.01,
    logging_dir="./logs",
    report_to="none"
)

# ✅ Trainer setup
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset
)

# ✅ Train the model
trainer.train()

# %%
def predict_sentiment(sentence):
    # ✅ Tokenize input sentence
    inputs = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True, max_length=512)

    # Move input tensors to the same device as the model
    inputs = inputs.to(model.device)

    # ✅ Perform inference (disable gradient calculation for efficiency)
    with torch.no_grad():
        outputs = model(**inputs)

    # ✅ Get predicted class (0 = Negative, 1 = Neutral, 2 = Positive)
    predicted_class = torch.argmax(outputs.logits, dim=1).item()

    # ✅ Convert class index to label
    label_map = {0: "Negative", 1: "Neutral", 2: "Positive"}
    return label_map[predicted_class]

# %%
print(predict_sentiment("J'adore ce produit, il est incroyable !"))  # Positive
print(predict_sentiment("C'est un produit moyen, pas mal mais rien d'exceptionnel."))  # Neutral
print(predict_sentiment("Je déteste ce produit, il est horrible."))  # Negative
# Out:
# Positive
# Positive
# Negative

# %%
print(predict_sentiment("Mauvais"))  # Negative
print(predict_sentiment("Bien"))  # Positive
# Out:
# Negative
# Positive

# %%
# %%capture
# !pip install huggingface_hub

# %%
# ✅ Define your Hugging Face repository name
repo_name = "Minervus00/camembert-fb-sentiment"

# ✅ Save the model and tokenizer
model.save_pretrained(repo_name)
tokenizer.save_pretrained(repo_name)
# Out:
# ('Minervus00/camembert-fb-sentiment/tokenizer_config.json',
#  'Minervus00/camembert-fb-sentiment/special_tokens_map.json',
#  'Minervus00/camembert-fb-sentiment/sentencepiece.bpe.model',
#  'Minervus00/camembert-fb-sentiment/added_tokens.json')

# %%
from google.colab import userdata
HF_TOKEN = userdata.get('HF_WRITE')

# %%
# ✅ Push model to Hugging Face Hub
model.push_to_hub(repo_name, token=HF_TOKEN)
tokenizer.push_to_hub(repo_name, token=HF_TOKEN)
# Out:
# README.md:   0%|          | 0.00/5.17k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/443M [00:00<?, ?B/s]
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING:huggingface_hub.hf_api:No files have been modified since last commit. Skipping to prevent empty commit.
# CommitInfo(commit_url='https://huggingface.co/Minervus00/camembert-fb-sentiment/commit/21201e57278d8086e641e0c6b3d8a0c7d547329f', commit_message='Upload tokenizer', commit_description='', oid='21201e57278d8086e641e0c6b3d8a0c7d547329f', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Minervus00/camembert-fb-sentiment', endpoint='https://huggingface.co', repo_type='model', repo_id='Minervus00/camembert-fb-sentiment'), pr_revision=None, pr_num=None)

# %%
from transformers import CamembertForSequenceClassification, CamembertTokenizer
import torch

# ✅ Load model & tokenizer from Hugging Face
repo_name = "Minervus00/camembert-fb-sentiment"  # Replace with your repo
model = CamembertForSequenceClassification.from_pretrained(repo_name)
tokenizer = CamembertTokenizer.from_pretrained(repo_name)

# ✅ Set model to evaluation mode
model.eval()

# ✅ Function to predict sentiment
def predict_sentiment(sentence):
    inputs = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True, max_length=512)

    with torch.no_grad():
        outputs = model(**inputs)

    predicted_class = torch.argmax(outputs.logits, dim=1).item()

    label_map = {0: "Negative", 1: "Neutral", 2: "Positive"}
    return label_map[predicted_class]

# ✅ Test predictions
print(predict_sentiment("J'adore ce produit, il est incroyable !"))  # Positive
print(predict_sentiment("C'est un produit moyen, pas mal mais rien d'exceptionnel."))  # Neutral
print(predict_sentiment("Je déteste ce produit, il est horrible."))  # Negative
# Out:
# config.json:   0%|          | 0.00/918 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/443M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.81k [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/811k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/22.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/374 [00:00<?, ?B/s]
# Neutral
# Neutral
# Neutral

# %% [markdown]
# ### Semi-supervised

# %%
df2 = pd.read_csv("second_step.csv")
df2
# Out:
#                                                    post  \
# 0                  Notre armée est notre fierté. 🇧🇫🇲🇱🇳🇪
# 1                  Notre armée est notre fierté. 🇧🇫🇲🇱🇳🇪
# 2                  Notre armée est notre fierté. 🇧🇫🇲🇱🇳🇪
# 3                  Notre armée est notre fierté. 🇧🇫🇲🇱🇳🇪
# 4                  Notre armée est notre fierté. 🇧🇫🇲🇱🇳🇪
# ...                                                 ...
# 1995  Si je n’ai pas eu Kundé cette année j’arrête d...
# 1996  Si je n’ai pas eu Kundé cette année j’arrête d...
# 1997  Si je n’ai pas eu Kundé cette année j’arrête d...
# 1998  Si je n’ai pas eu Kundé cette année j’arrête d...
# 1999  Si je n’ai pas eu Kundé cette année j’arrête d...
#
#                                                 comment  likes
# 0     Sans doute, beaucoup copieront des bons exempl...     11
# 1     Une armée devant laquelle les tero tero endeui...      8
# 2     Vive mon faso et qu Allah ns protège tous cour...      0
# 3                               Vive notre armée 🇧🇫🇲🇱🇳🇪     10
# 4     Nous c'est notre président qui est notre fiert...      8
# ...                                                 ...    ...
# 1995                                         C'est cool      0
# 1996  Ouais big up. J'attends ma commission en tant ...      0
# 1997       Sincèrement tu mérites le coundé cette année      0
# 1998                                       En mode 1980      0
# 1999       Damibatiquement, tu mérites un disque et dor      0
#
# [2000 rows x 3 columns]

# %%
train_df2 = df2.loc[:1499, ]
test_df2 = df2.loc[1500:, ]

# %%
train_df2["label"] = train_df2["comment"].apply(predict_sentiment)
train_df2
# Out:
# <ipython-input-25-293f549d5612>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df2["label"] = train_df2["comment"].apply(predict_sentiment)
#                                                post  \
# 0              Notre armée est notre fierté. 🇧🇫🇲🇱🇳🇪
# 1              Notre armée est notre fierté. 🇧🇫🇲🇱🇳🇪
# 2              Notre armée est notre fierté. 🇧🇫🇲🇱🇳🇪
# 3              Notre armée est notre fierté. 🇧🇫🇲🇱🇳🇪
# 4              Notre armée est notre fierté. 🇧🇫🇲🇱🇳🇪
# ...                                             ...
# 1495  Franchement ça n’a pas été simple pour Floby😎
# 1496  Franchement ça n’a pas été simple pour Floby😎
# 1497  Franchement ça n’a pas été simple pour Floby😎
# 1498  Franchement ça n’a pas été simple pour Floby😎
# 1499  Franchement ça n’a pas été simple pour Floby😎
#
#                                                 comment  likes     label
# 0     Sans doute, beaucoup copieront des bons exempl...     11  Positive
# 1     Une armée devant laquelle les tero tero endeui...      8   Neutral
# 2     Vive mon faso et qu Allah ns protège tous cour...      0  Positive
# 3                               Vive notre armée 🇧🇫🇲🇱🇳🇪     10   Neutral
# 4     Nous c'est notre président qui est notre fiert...      8  Positive
# ...                                                 ...    ...       ...
# 1495                    En tout cas pour toi était bon😅      2  Positive
# 1496                                Ni pour l'autre 🤣🤣🤣      0   Neutral
# 1497  C'est vraiment pas facile de sourire lorsqu'on...      0  Positive
# 1498                                         Lo vieux😹😹      0   Neutral
# 1499                                       Et toi mm😂😂😂      0   Neutral
#
# [1500 rows x 4 columns]

# %%
train_df2 = train_df2.drop(columns=["post", "likes"])
train_df2 = train_df2.rename(columns={"comment": "text"})
train_df2
# Out:
#                                                    text     label
# 0     Sans doute, beaucoup copieront des bons exempl...  Positive
# 1     Une armée devant laquelle les tero tero endeui...   Neutral
# 2     Vive mon faso et qu Allah ns protège tous cour...  Positive
# 3                               Vive notre armée 🇧🇫🇲🇱🇳🇪   Neutral
# 4     Nous c'est notre président qui est notre fiert...  Positive
# ...                                                 ...       ...
# 1495                    En tout cas pour toi était bon😅  Positive
# 1496                                Ni pour l'autre 🤣🤣🤣   Neutral
# 1497  C'est vraiment pas facile de sourire lorsqu'on...  Positive
# 1498                                         Lo vieux😹😹   Neutral
# 1499                                       Et toi mm😂😂😂   Neutral
#
# [1500 rows x 2 columns]

# %%
train_df2["label"] = train_df2["label"].map({"Negative": 0, "Neutral": 1, "Positive": 2})
train_df2.head()
# Out:
#                                                 text  label
# 0  Sans doute, beaucoup copieront des bons exempl...      2
# 1  Une armée devant laquelle les tero tero endeui...      1
# 2  Vive mon faso et qu Allah ns protège tous cour...      2
# 3                            Vive notre armée 🇧🇫🇲🇱🇳🇪      1
# 4  Nous c'est notre président qui est notre fiert...      2

# %%
train_df2["label"].value_counts()
# Out:
# label
# 1    795
# 2    485
# 0    220
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
# ✅ Split dataset: 80% train, 20% validation
train_set, val_set = train_test_split(train_df2, test_size=0.2, random_state=42)

# ✅ Convert Pandas DataFrame to Hugging Face Dataset
train_dataset = Dataset.from_pandas(train_set)
val_dataset = Dataset.from_pandas(val_set)

# %%
# ✅ Tokenization function
# def tokenize_function(examples):
#     return tokenizer(examples["text"], padding="max_length", truncation=True)

# %%
# ✅ Tokenize datasets
train_dataset = train_dataset.map(tokenize_function, batched=True)
val_dataset = val_dataset.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/1200 [00:00<?, ? examples/s]
# Map:   0%|          | 0/300 [00:00<?, ? examples/s]

# %%
# ✅ Training arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=10,
    weight_decay=0.01,
    logging_dir="./logs",
    report_to="none"
)

# ✅ Trainer setup
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset
)

# ✅ Train the model
trainer.train()
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='1500' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1500/1500 21:32, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.194076</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.184031</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.213460</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.228800</td>
#       <td>0.349211</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.228800</td>
#       <td>0.323455</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.228800</td>
#       <td>0.344875</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.044600</td>
#       <td>0.314840</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.044600</td>
#       <td>0.351504</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.044600</td>
#       <td>0.397450</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.014600</td>
#       <td>0.396732</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1500, training_loss=0.09597844632466634, metrics={'train_runtime': 1293.2108, 'train_samples_per_second': 9.279, 'train_steps_per_second': 1.16, 'total_flos': 3157361012736000.0, 'train_loss': 0.09597844632466634, 'epoch': 10.0})

# %%
model.eval()

# ✅ Function to predict sentiment
def predict_sentiment(sentence):
    # ✅ Tokenize input sentence
    inputs = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True, max_length=512)

    # Move input tensors to the same device as the model
    inputs = inputs.to(model.device)

    # ✅ Perform inference (disable gradient calculation for efficiency)
    with torch.no_grad():
        outputs = model(**inputs)

    # ✅ Get predicted class (0 = Negative, 1 = Neutral, 2 = Positive)
    predicted_class = torch.argmax(outputs.logits, dim=1).item()

    # ✅ Convert class index to label
    label_map = {0: "Negative", 1: "Neutral", 2: "Positive"}
    return label_map[predicted_class]

# ✅ Test predictions
print(predict_sentiment("J'adore ce produit, il est incroyable !"))  # Positive
print(predict_sentiment("C'est un produit moyen, pas mal mais rien d'exceptionnel."))  # Neutral
print(predict_sentiment("Je déteste ce produit, il est horrible."))  # Negative
# Out:
# Positive
# Positive
# Negative

# %%
test_df2["label"] = test_df2["comment"].apply(predict_sentiment)
test_df2
# Out:
# <ipython-input-33-92df9bd1911b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df2["label"] = test_df2["comment"].apply(predict_sentiment)
#                                                    post  \
# 1500  Si je n’ai pas eu Kundé cette année j’arrête d...
# 1501  Si je n’ai pas eu Kundé cette année j’arrête d...
# 1502  Si je n’ai pas eu Kundé cette année j’arrête d...
# 1503  Si je n’ai pas eu Kundé cette année j’arrête d...
# 1504  Si je n’ai pas eu Kundé cette année j’arrête d...
# ...                                                 ...
# 1995  Si je n’ai pas eu Kundé cette année j’arrête d...
# 1996  Si je n’ai pas eu Kundé cette année j’arrête d...
# 1997  Si je n’ai pas eu Kundé cette année j’arrête d...
# 1998  Si je n’ai pas eu Kundé cette année j’arrête d...
# 1999  Si je n’ai pas eu Kundé cette année j’arrête d...
#
#                                                 comment  likes     label
# 1500                                Yam bigapamin biiii    335   Neutral
# 1501                     Kundé d’or en téléchargement 😂     88   Neutral
# 1502  🤣🤣🤣 walaï il est trop fort. Que Dieu te béniss...     30  Positive
# 1503  El Présidente Bf  ah tu es bon champion, qu'Al...     22  Positive
# 1504                                            Bigap 🤣     22   Neutral
# ...                                                 ...    ...       ...
# 1995                                         C'est cool      0  Positive
# 1996  Ouais big up. J'attends ma commission en tant ...      0  Positive
# 1997       Sincèrement tu mérites le coundé cette année      0  Positive
# 1998                                       En mode 1980      0   Neutral
# 1999       Damibatiquement, tu mérites un disque et dor      0  Positive
#
# [500 rows x 4 columns]

# %%
test_df2["label"].value_counts()
# Out:
# label
# Positive    293
# Neutral     172
# Negative     35
# Name: count, dtype: int64

# %%
val = test_df2.drop(columns=["post", "likes"])
val = val.rename(columns={"comment": "text"})
val
# Out:
#                                                    text     label
# 1500                                Yam bigapamin biiii   Neutral
# 1501                     Kundé d’or en téléchargement 😂   Neutral
# 1502  🤣🤣🤣 walaï il est trop fort. Que Dieu te béniss...  Positive
# 1503  El Présidente Bf  ah tu es bon champion, qu'Al...  Positive
# 1504                                            Bigap 🤣   Neutral
# ...                                                 ...       ...
# 1995                                         C'est cool  Positive
# 1996  Ouais big up. J'attends ma commission en tant ...  Positive
# 1997       Sincèrement tu mérites le coundé cette année  Positive
# 1998                                       En mode 1980   Neutral
# 1999       Damibatiquement, tu mérites un disque et dor  Positive
#
# [500 rows x 2 columns]

# %%
val.to_csv("final_pred.csv", index=False)

# %%
# ✅ Define your Hugging Face repository name
repo_name = "Minervus00/camembert-fb-sentiment-2"

# ✅ Save the model and tokenizer
model.save_pretrained(repo_name)
tokenizer.save_pretrained(repo_name)
# Out:
# ('Minervus00/camembert-fb-sentiment-2/tokenizer_config.json',
#  'Minervus00/camembert-fb-sentiment-2/special_tokens_map.json',
#  'Minervus00/camembert-fb-sentiment-2/sentencepiece.bpe.model',
#  'Minervus00/camembert-fb-sentiment-2/added_tokens.json')

# %%
from google.colab import userdata
HF_TOKEN = userdata.get('HF_WRITE')

# %%
# ✅ Push model to Hugging Face Hub
model.push_to_hub(repo_name, token=HF_TOKEN)
tokenizer.push_to_hub(repo_name, token=HF_TOKEN)
# Out:
# README.md:   0%|          | 0.00/5.17k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/443M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Minervus00/camembert-fb-sentiment-2/commit/5e7a6146dbf635a4091d954e9c23b64ec77904d1', commit_message='Upload tokenizer', commit_description='', oid='5e7a6146dbf635a4091d954e9c23b64ec77904d1', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Minervus00/camembert-fb-sentiment-2', endpoint='https://huggingface.co', repo_type='model', repo_id='Minervus00/camembert-fb-sentiment-2'), pr_revision=None, pr_num=None)

# %%
from transformers import CamembertForSequenceClassification, CamembertTokenizer
import torch

# ✅ Load model & tokenizer from Hugging Face
repo_name = "Minervus00/camembert-fb-sentiment-2"  # Replace with your repo
model = CamembertForSequenceClassification.from_pretrained(repo_name)
tokenizer = CamembertTokenizer.from_pretrained(repo_name)

# ✅ Set model to evaluation mode
model.eval()

# %%
def predict_sentiment(sentence):
    # ✅ Tokenize input sentence
    inputs = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True, max_length=512)

    # Move input tensors to the same device as the model
    inputs = inputs.to(model.device)

    # ✅ Perform inference (disable gradient calculation for efficiency)
    with torch.no_grad():
        outputs = model(**inputs)

    # ✅ Get predicted class (0 = Negative, 1 = Neutral, 2 = Positive)
    predicted_class = torch.argmax(outputs.logits, dim=1).item()

    # ✅ Convert class index to label
    label_map = {0: "Negative", 1: "Neutral", 2: "Positive"}
    return label_map[predicted_class]

# ✅ Test predictions
print(predict_sentiment("J'adore ce produit, il est incroyable !"))  # Positive
print(predict_sentiment("C'est un produit moyen, pas mal mais rien d'exceptionnel."))  # Neutral
print(predict_sentiment("Je déteste ce produit, il est horrible."))  # Negative
